# %% [markdown]
# ### HOUSE RENT DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings('ignore')
from sklearn import svm

# %%
df=pd.read_csv("/content/drive/MyDrive/ML/Class5/House_Rent_Dataset.csv")
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
target = list()
for val in df['BHK']:
  if val < 2:
    target.append(0)
  elif val >= 2 and val < 4:
    target.append(1)
  else:
    target.append(2)

# %%
df["target"] = target
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact  target
# 0         2    Contact Owner       1
# 1         1    Contact Owner       1
# 2         1    Contact Owner       1
# 3         1    Contact Owner       1
# 4         1    Contact Owner       1

# %%
area_type = {
    'Super Area': 0, 
    'Carpet Area': 1, 
    'Built Area': 2
}

fur_status = {
    'Semi-Furnished': 0, 
    'Unfurnished': 1, 
    'Furnished': 2
}

city = {
 'Kolkata': 0,
 'Bangalore': 1,
 'Mumbai': 2,
 'Chennai': 3,
 'Hyderabad': 4,
 'Delhi': 5,
}

tenant = {
    'Bachelors/Family': 0,
    'Bachelors': 1,
    'Family': 2
}
contact = {
    'Contact Owner': 0,
    'Contact Agent': 1,
    'Contact Builder': 2
}

# %%
df['Area Type'] = df['Area Type'].apply(lambda x: area_type[x])
df['Furnishing Status'] = df['Furnishing Status'].apply(lambda x: fur_status[x])
df['City'] = df['City'].apply(lambda x: city[x])
df['Tenant Preferred'] = df['Tenant Preferred'].apply(lambda x: tenant[x])
df['Point of Contact'] = df['Point of Contact'].apply(lambda x: contact[x])

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor  Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2          0
# 1  2022-05-13    2  20000   800       1 out of 3          0
# 2  2022-05-16    2  17000  1000       1 out of 3          0
# 3  2022-07-04    2  10000   800       1 out of 2          0
# 4  2022-05-09    2   7500   850       1 out of 2          1
#
#               Area Locality  City  Furnishing Status  Tenant Preferred  \
# 0                    Bandel     0                  1                 0
# 1  Phool Bagan, Kankurgachi     0                  0                 0
# 2   Salt Lake City Sector 2     0                  0                 0
# 3               Dumdum Park     0                  1                 0
# 4             South Dum Dum     0                  1                 1
#
#    Bathroom  Point of Contact  target
# 0         2                 0       1
# 1         1                 0       1
# 2         1                 0       1
# 3         1                 0       1
# 4         1                 0       1

# %%
df.corr()
# Out:
#                         BHK      Rent      Size  Area Type      City  \
# BHK                1.000000  0.369718  0.716145   0.153225  0.091828
# Rent               0.369718  1.000000  0.413551   0.214867 -0.023734
# Size               0.716145  0.413551  1.000000   0.079705  0.060177
# Area Type          0.153225  0.214867  0.079705   1.000000 -0.087328
# City               0.091828 -0.023734  0.060177  -0.087328  1.000000
# Furnishing Status -0.072916  0.022612 -0.089949   0.025982 -0.001296
# Tenant Preferred   0.123609  0.082496  0.109498   0.308650 -0.012251
# Bathroom           0.794885  0.441215  0.740703   0.183012  0.131302
# Point of Contact   0.229764  0.338966  0.213436   0.558047 -0.020005
# target             0.865674  0.295662  0.590853   0.106028  0.074525
#
#                    Furnishing Status  Tenant Preferred  Bathroom  \
# BHK                        -0.072916          0.123609  0.794885
# Rent                        0.022612          0.082496  0.441215
# Size                       -0.089949          0.109498  0.740703
# Area Type                   0.025982          0.308650  0.183012
# City                       -0.001296         -0.012251  0.131302
# Furnishing Status           1.000000          0.002795 -0.063716
# Tenant Preferred            0.002795          1.000000  0.144298
# Bathroom                   -0.063716          0.144298  1.000000
# Point of Contact            0.014395          0.242072  0.326490
# target                     -0.068883          0.094210  0.674680
#
#                    Point of Contact    target
# BHK                        0.229764  0.865674
# Rent                       0.338966  0.295662
# Size                       0.213436  0.590853
# Area Type                  0.558047  0.106028
# City                      -0.020005  0.074525
# Furnishing Status          0.014395 -0.068883
# Tenant Preferred           0.242072  0.094210
# Bathroom                   0.326490  0.674680
# Point of Contact           1.000000  0.141743
# target                     0.141743  1.000000

# %%
#df.drop(['Posted On', 'Area Locality', 'Floor'], axis = 'columns', inplace = True)
#df

area_locality = df['Area Locality'].value_counts().to_dict()
for i, k in enumerate(area_locality):
  area_locality[k] = i

df['Area Locality'] = df['Area Locality'].apply(lambda x: area_locality[x])
df.corr()
# Out:
#                         BHK      Rent      Size  Area Type  Area Locality  \
# BHK                1.000000  0.369718  0.716145   0.153225      -0.027987
# Rent               0.369718  1.000000  0.413551   0.214867       0.047623
# Size               0.716145  0.413551  1.000000   0.079705      -0.059827
# Area Type          0.153225  0.214867  0.079705   1.000000       0.141167
# Area Locality     -0.027987  0.047623 -0.059827   0.141167       1.000000
# City               0.091828 -0.023734  0.060177  -0.087328      -0.121784
# Furnishing Status -0.072916  0.022612 -0.089949   0.025982       0.041867
# Tenant Preferred   0.123609  0.082496  0.109498   0.308650       0.039508
# Bathroom           0.794885  0.441215  0.740703   0.183012       0.011115
# Point of Contact   0.229764  0.338966  0.213436   0.558047       0.033620
# target             0.865674  0.295662  0.590853   0.106028      -0.036818
#
#                        City  Furnishing Status  Tenant Preferred  Bathroom  \
# BHK                0.091828          -0.072916          0.123609  0.794885
# Rent              -0.023734           0.022612          0.082496  0.441215
# Size               0.060177          -0.089949          0.109498  0.740703
# Area Type         -0.087328           0.025982          0.308650  0.183012
# Area Locality     -0.121784           0.041867          0.039508  0.011115
# City               1.000000          -0.001296         -0.012251  0.131302
# Furnishing Status -0.001296           1.000000          0.002795 -0.063716
# Tenant Preferred  -0.012251           0.002795          1.000000  0.144298
# Bathroom           0.131302          -0.063716          0.144298  1.000000
# Point of Contact  -0.020005           0.014395          0.242072  0.326490
# target             0.074525          -0.068883          0.094210  0.674680
#
#                    Point of Contact    target
# BHK                        0.229764  0.865674
# Rent                       0.338966  0.295662
# Size                       0.213436  0.590853
# Area Type                  0.558047  0.106028
# Area Locality              0.033620 -0.036818
# City                      -0.020005  0.074525
# Furnishing Status          0.014395 -0.068883
# Tenant Preferred           0.242072  0.094210
# Bathroom                   0.326490  0.674680
# Point of Contact           1.000000  0.141743
# target                     0.141743  1.000000

# %%
floor = df['Floor'].value_counts().to_dict()
for i, k in enumerate(floor):
  floor[k] = i

df['Floor'] = df['Floor'].apply(lambda x: floor[x])
df.corr()
# Out:
#                         BHK      Rent      Size     Floor  Area Type  \
# BHK                1.000000  0.369718  0.716145  0.210955   0.153225
# Rent               0.369718  1.000000  0.413551  0.298625   0.214867
# Size               0.716145  0.413551  1.000000  0.171089   0.079705
# Floor              0.210955  0.298625  0.171089  1.000000   0.261584
# Area Type          0.153225  0.214867  0.079705  0.261584   1.000000
# Area Locality     -0.027987  0.047623 -0.059827  0.124971   0.141167
# City               0.091828 -0.023734  0.060177 -0.072745  -0.087328
# Furnishing Status -0.072916  0.022612 -0.089949  0.017383   0.025982
# Tenant Preferred   0.123609  0.082496  0.109498  0.135703   0.308650
# Bathroom           0.794885  0.441215  0.740703  0.312276   0.183012
# Point of Contact   0.229764  0.338966  0.213436  0.409726   0.558047
# target             0.865674  0.295662  0.590853  0.148961   0.106028
#
#                    Area Locality      City  Furnishing Status  \
# BHK                    -0.027987  0.091828          -0.072916
# Rent                    0.047623 -0.023734           0.022612
# Size                   -0.059827  0.060177          -0.089949
# Floor                   0.124971 -0.072745           0.017383
# Area Type               0.141167 -0.087328           0.025982
# Area Locality           1.000000 -0.121784           0.041867
# City                   -0.121784  1.000000          -0.001296
# Furnishing Status       0.041867 -0.001296           1.000000
# Tenant Preferred        0.039508 -0.012251           0.002795
# Bathroom                0.011115  0.131302          -0.063716
# Point of Contact        0.033620 -0.020005           0.014395
# target                 -0.036818  0.074525          -0.068883
#
#                    Tenant Preferred  Bathroom  Point of Contact    target
# BHK                        0.123609  0.794885          0.229764  0.865674
# Rent                       0.082496  0.441215          0.338966  0.295662
# Size                       0.109498  0.740703          0.213436  0.590853
# Floor                      0.135703  0.312276          0.409726  0.148961
# Area Type                  0.308650  0.183012          0.558047  0.106028
# Area Locality              0.039508  0.011115          0.033620 -0.036818
# City                      -0.012251  0.131302         -0.020005  0.074525
# Furnishing Status          0.002795 -0.063716          0.014395 -0.068883
# Tenant Preferred           1.000000  0.144298          0.242072  0.094210
# Bathroom                   0.144298  1.000000          0.326490  0.674680
# Point of Contact           0.242072  0.326490          1.000000  0.141743
# target                     0.094210  0.674680          0.141743  1.000000

# %%
df.drop(['Posted On', 'BHK'], axis = 'columns', inplace = True)
df.head()
# Out:
#     Rent  Size  Floor  Area Type  Area Locality  City  Furnishing Status  \
# 0  10000  1100      1          0            507     0                  1
# 1  20000   800      4          0            465     0                  0
# 2  17000  1000      4          0             13     0                  0
# 3  10000   800      0          0            737     0                  1
# 4   7500   850      0          1           1251     0                  1
#
#    Tenant Preferred  Bathroom  Point of Contact  target
# 0                 0         2                 0       1
# 1                 0         1                 0       1
# 2                 0         1                 0       1
# 3                 0         1                 0       1
# 4                 1         1                 0       1

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 2000)

# %%
model = svm.SVC()
model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
model.score(X_test, Y_test)
# Out:
# 0.7305263157894737

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_train, Y_train)
classifier.score(X_test, Y_test)
# Out:
# 0.8557894736842105
